# %% [markdown]
# # <a name="top">Exercise 2: HGNC and MySQL</span>

# %% [markdown]
# ## Table of content
# 0. <a href="#import_and_preparations">Imports and preparations</a>
# 0. <a href="#problem">Defining the problem</a>
# 0. <a href="#objective">Objective</a>
# 0. <a href="#tasks_in_general">Tasks in general</a>
# 0. <a href="#tasks">Tasks</a>
# 0. <a href="#problem">Defining the problem</a>

# %% [markdown]
# ## <a id="import_and_preparations">Imports and preparations</a>

# %%
import pandas as pd
import os , json, pymysql, re
base = os.path.join(os.environ['BUG_FREE_EUREKA_BASE'])
# %matplotlib inline

# %%
pathToFile = os.path.join(base,'data','exercise05','nodes_in_Alzheimer_BEL_disease_network.tsv')
df = pd.read_table(pathToFile)

# %% [markdown]
# ## <a id="problem">Defining the problem</a>
# We have already loaded a list of biological entities in the context of Alzheimer's disease in a pandas `DataFrame`. The column **`value`** identifies in this `DataFrame` biological entities in specific namespace (stored in the column `namespace`). **`namespace`** and **`value`** together are a ***unique identifier*** for the entities.
#
# One of the most used namespaces in our dataset is HGNC. The HGNC database is maintained by the HUGO  Gene Nomenclature Committee and stores approved gene names, symbols (short-form abbreviation, column our `value`) and addtional information about genes.
#
# OK, even we have now a clear identify with the short name in our `DataFrame`: But do you know the recommended names of these short names, to which gene family they belong or the gene ID from NCBI?

# %%
list(df[(df.namespace=='HGNC')].value[:10])
# Out:
# ['BACE1',
#  'APP',
#  'CLSTN1',
#  'KLC1',
#  'PSEN1',
#  'NCSTN',
#  'APH1A',
#  'PSEN2',
#  'ARRB2',
#  'GPR3']

# %% [markdown]
#  Ice cream for all if you can give me all recommended names (without any further search)!

# %% [markdown]
# ## <a id="objective">Objective</a>
# + Find new insights into Alzheimer's disease by analysing the information about genes

# %% [markdown]
# ## <a id="tasks_in_general">Tasks in general</a>

# %% [markdown]
#    0. Analyse the JSON file, find a way to automatically scan the whole json for datatypes
#    0. Connect to MySQL, create database
#    0. Create appropriate tables in MySQL database
#    0. Store the data in the database
#    0. Find the gene family with the highest frequency
#        + by combining
#            + pandas dataframe
#            + MySQL database
#        + loading database into dataframe
#        + loading dataframe into database
#
# links:
# + [Reference manual](http://dev.mysql.com/doc/refman/5.7/en/)
# + [HUGO Gene Nomenclature Committee (HGNC)](http://www.genenames.org/)

# %% [markdown]
# ## <a id="tasks">Tasks</a>

# %% [markdown]
# ### Load the JSON file

# %% [markdown]
# The data is in the JSON format - this means that all atomic data is in nested dictionaries and lists.

# %%
data_path = os.path.join(base,'data', 'exercise02', 'hgnc_complete_set.json')

with open(data_path) as f:
    hgnc_json = json.load(f)

# %% [markdown]
# ### Exploration of data structure
#
# We want to understand what data is inside this json. To do this, we'll look at the keys of each nested dictionary.
#
# The first set of keys shows that there is a response (the data) and a response header (data about the way it was downloaded). We will further explore the response.

# %%
hgnc_json.keys()
# Out:
# dict_keys(['response', 'responseHeader'])

# %% [markdown]
# The response contains `numFound`, which lists how many results there are in `docs`. Disregard `start`.

# %%
hgnc_json['response'].keys()
# Out:
# dict_keys(['numFound', 'docs', 'start'])

# %%
hgnc_json['response']['docs'][0] # try wz .keys() # it is 1 to 1 RS and 1 to many RS
# Out:
# {'_version_': 1546503090507612160,
#  'ccds_id': ['CCDS12976'],
#  'cosmic': 'A1BG',
#  'date_approved_reserved': '1989-06-30',
#  'date_modified': '2015-07-13',
#  'ensembl_gene_id': 'ENSG00000121410',
#  'entrez_id': '1',
#  'gene_family': ['Immunoglobulin like domain containing'],
#  'gene_family_id': [594],
#  'hgnc_id': 'HGNC:5',
#  'location': '19q13.43',
#  'location_sortable': '19q13.43',
#  'locus_group': 'protein-coding gene',
#  'locus_type': 'gene with protein product',
#  'merops': 'I43.950',
#  'mgd_id': ['MGI:2152878'],
#  'name': 'alpha-1-B glycoprotein',
#  'omim_id': [138670],
#  'pubmed_id': [2591067],
#  'refseq_accession': ['NM_130786'],
#  'rgd_id': ['RGD:69417'],
#  'status': 'Approved',
#  'symbol': 'A1BG',
#  'ucsc_id': 'uc002qsd.5',
#  'uniprot_ids': ['P04217'],
#  'uuid': 'c5fd27c5-7aa4-447c-83b0-1ccc73d90925',
#  'vega_id': 'OTTHUMG00000183507'}

# %% [markdown]
# `docs` is a list where each entry is the data associated with a gene. Below is an example of the first element of this list:

# %%
print(json.dumps(hgnc_json['response']['docs'][0], indent=5)) # to be nicely formated
# Out:
# {
#      "uniprot_ids": [
#           "P04217"
#      ],
#      "ccds_id": [
#           "CCDS12976"
#      ],
#      "locus_type": "gene with protein product",
#      "date_modified": "2015-07-13",
#      "refseq_accession": [
#           "NM_130786"
#      ],
#      "ucsc_id": "uc002qsd.5",
#      "mgd_id": [
#           "MGI:2152878"
#      ],
#      "gene_family": [
#           "Immunoglobulin like domain containing"
#      ],
#      "merops": "I43.950",
#      "_version_": 1546503090507612160,
#      "location_sortable": "19q13.43",
#      "entrez_id": "1",
#      "locus_group": "protein-coding gene",
#      "cosmic": "A1BG",
#      "omim_id": [
#           138670
#      ],
#      "ensembl_gene_id": "ENSG00000121410",
#      "uuid": "c5fd27c5-7aa4-447c-83b0-1ccc73d90925",
#      "hgnc_id": "HGNC:5",
#      "gene_family_id": [
#           594
#      ],
#      "symbol": "A1BG",
#      "pubmed_id": [
#           2591067
#      ],
#      "vega_id": "OTTHUMG00000183507",
#      "name": "alpha-1-B glycoprotein",
#      "date_approved_reserved": "1989-06-30",
#      "status": "Approved",
#      "location": "19q13.43",
#      "rgd_id": [
#           "RGD:69417"
#      ]
# }

# %% [markdown]
# ### Create a Database Schema
#
# Analyze the structure of each entry. Depending on the data type, decide what sort of relation you need to store the data. For example, a list would correspond to a 1-to-many relationship, while an atomic would correspond to a 1-to-1.
#
# Your goal is to connect to your database, build an appropriate schema, and upload the data from the hgnc_json file.
#
# Choose one 1-to-n relationship and some 1-to-1 for your schema.

# %%
secrets_path = os.path.join(base, 'secrets.json')

with open(secrets_path) as f:
    secrets = json.load(f)

print(json.dumps(secrets, indent=2))
# Out:
# {
#   "test_db": {
#     "host": "localhost",
#     "db": "mysql",
#     "user": "root",
#     "password": "1234",
#     "port": 3306
#   }
# }

# %%
pd.io.sql._SQL_TYPES['string']['mysql']='VARCHAR (255)' # fixes the problem of too short varchar fields

# %%
db_params = secrets['test_db']

conn = pymysql.connect(**db_params) # **

# %%
schema_sql = """
select 'YOUR CODE HERE'
"""

with conn.cursor(pymysql.cursors.DictCursor) as cursor:
    cursor.execute(schema_sql)
    print(*cursor.fetchone())
# Out:
# YOUR CODE HERE

# %% [markdown]
# ## ToDos
# + create a database with the name `hgnc`
# + Analyse you data structure by iterating over the data and identify
#     + datatypes
#     + relationship type (1 to 1, 1 to many)
# + use a new cursor  to execute the same statement over entry of `docs`.
# + follow the suggestions below
# + Upload the Data

# %% [markdown]
# ## Solution

# %% [markdown]
# ## Create the database

# %%
# create database hereconn = pymysql.Connect(**secrets['test_db']) # to use sql
cursor = conn.cursor() 

cursor.execute(' create database if not exists hgnc')
# Out:
# C:\Users\randa\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1007, "Can't create database 'hgnc'; database exists")
#   result = self._query(query)
# 1

# %%
#check if table is created
cursor.execute("show tables")
cursor.fetchall()
# Out:
# (('columns_priv',),
#  ('db',),
#  ('dea',),
#  ('engine_cost',),
#  ('event',),
#  ('func',),
#  ('general_log',),
#  ('gtid_executed',),
#  ('help_category',),
#  ('help_keyword',),
#  ('help_relation',),
#  ('help_topic',),
#  ('innodb_index_stats',),
#  ('innodb_table_stats',),
#  ('ndb_binlog_index',),
#  ('plugin',),
#  ('proc',),
#  ('procs_priv',),
#  ('proxies_priv',),
#  ('server_cost',),
#  ('servers',),
#  ('slave_master_info',),
#  ('slave_relay_log_info',),
#  ('slave_worker_info',),
#  ('slow_log',),
#  ('tables_priv',),
#  ('time_zone',),
#  ('time_zone_leap_second',),
#  ('time_zone_name',),
#  ('time_zone_transition',),
#  ('time_zone_transition_type',),
#  ('user',))

# %% [markdown]
# ### Analyse you data structure by iterating over the data

# %%
docs = hgnc_json['response']['docs'] # my data
print(type(docs))
# Out:
# <class 'list'>

# %%
dataTypes={'column1':[int],'column2':[str,int]} 

 # if the json mix up data types
# ... write here your code ti fill up the dataTypes dictionary like dataType = {'column1':[int],'column2':[str,int],...}
# you will find only int strn list in HGNC

# %%
df.describe()
# Out:
# C:\Users\randa\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             node_id     node_id.1       position
# count  11927.000000  11927.000000     130.000000
# mean    5964.000000   5964.000000    2595.946154
# std     3443.172665   3443.172665   24114.045581
# min        1.000000      1.000000       4.000000
# 25%     2982.500000   2982.500000            NaN
# 50%     5964.000000   5964.000000            NaN
# 75%     8945.500000   8945.500000            NaN
# max    11927.000000  11927.000000  275341.000000

# %%
df.head(20) # checking rows
# Out:
#     node_id                                                BEL  \
# 0         1               a(CHEBI:"gamma-secretase inhibitor")
# 1         2           complex(SCOMP:"gamma Secretase Complex")
# 2         3                                    p(HGNC:"BACE1")
# 3         4  reaction(reactants(p(HGNC:APP)),products(a(ADO...
# 4         5                                      p(HGNC:"APP")
# 5         6                                  a(ADO:"Abeta_42")
# 6         7                    path(MESHD:"Alzheimer Disease")
# 7         8                                   p(HGNC:"CLSTN1")
# 8         9               complex(p(HGNC:CLSTN1),p(HGNC:KLC1))
# 9        10                                     p(HGNC:"KLC1")
# 10       11                      bp(MESHPP:"Axonal Transport")
# 11       12  list(p(HGNC:PSEN1),p(HGNC:NCSTN),p(HGNC:APH1A)...
# 12       13                                    p(HGNC:"PSEN1")
# 13       14                                    p(HGNC:"NCSTN")
# 14       15                                    p(HGNC:"APH1A")
# 15       16                                    p(HGNC:"PSEN2")
# 16       17          list(a(ADO:"Abeta_42"),a(ADO:"Abeta_40"))
# 17       18                                  a(ADO:"Abeta_40")
# 18       19                          a(CHEBI:"phenanthroline")
# 19       20         a(CHEBI:"ethylenediaminetetraacetic acid")
#
#    aminoacid_Code_1 aminoacid_Code_2  function  list modification namespace  \
# 0               NaN              NaN         a   NaN          NaN     CHEBI
# 1               NaN              NaN   complex   NaN          NaN     SCOMP
# 2               NaN              NaN         p   NaN          NaN      HGNC
# 3               NaN              NaN  reaction   NaN          NaN       NaN
# 4               NaN              NaN         p   NaN          NaN      HGNC
# 5               NaN              NaN         a   NaN          NaN       ADO
# 6               NaN              NaN      path   NaN          NaN     MESHD
# 7               NaN              NaN         p   NaN          NaN      HGNC
# 8               NaN              NaN   complex  True          NaN       NaN
# 9               NaN              NaN         p   NaN          NaN      HGNC
# 10              NaN              NaN        bp   NaN          NaN    MESHPP
# 11              NaN              NaN      list  True          NaN       NaN
# 12              NaN              NaN         p   NaN          NaN      HGNC
# 13              NaN              NaN         p   NaN          NaN      HGNC
# 14              NaN              NaN         p   NaN          NaN      HGNC
# 15              NaN              NaN         p   NaN          NaN      HGNC
# 16              NaN              NaN      list  True          NaN       NaN
# 17              NaN              NaN         a   NaN          NaN       ADO
# 18              NaN              NaN         a   NaN          NaN     CHEBI
# 19              NaN              NaN         a   NaN          NaN     CHEBI
#
#     node_id.1 p_modType  position undefined_namespace valid_NSV  \
# 0           1       NaN       NaN                 NaN       NaN
# 1           2       NaN       NaN                 NaN       NaN
# 2           3       NaN       NaN                 NaN      True
# 3           4       NaN       NaN                 NaN       NaN
# 4           5       NaN       NaN                 NaN      True
# 5           6       NaN       NaN                 NaN      True
# 6           7       NaN       NaN                 NaN      True
# 7           8       NaN       NaN                 NaN      True
# 8           9       NaN       NaN                 NaN       NaN
# 9          10       NaN       NaN                 NaN      True
# 10         11       NaN       NaN                 NaN      True
# 11         12       NaN       NaN                 NaN       NaN
# 12         13       NaN       NaN                 NaN      True
# 13         14       NaN       NaN                 NaN      True
# 14         15       NaN       NaN                 NaN      True
# 15         16       NaN       NaN                 NaN      True
# 16         17       NaN       NaN                 NaN       NaN
# 17         18       NaN       NaN                 NaN      True
# 18         19       NaN       NaN                 NaN      True
# 19         20       NaN       NaN                 NaN      True
#
#                               value
# 0         gamma-secretase inhibitor
# 1         "gamma Secretase Complex"
# 2                             BACE1
# 3                               NaN
# 4                               APP
# 5                          Abeta_42
# 6                 Alzheimer Disease
# 7                            CLSTN1
# 8                               NaN
# 9                              KLC1
# 10                 Axonal Transport
# 11                              NaN
# 12                            PSEN1
# 13                            NCSTN
# 14                            APH1A
# 15                            PSEN2
# 16                              NaN
# 17                         Abeta_40
# 18                   phenanthroline
# 19  ethylenediaminetetraacetic acid

# %%
df.set_index('node_id', inplace=True)#Let's set the index_id

# %%
df.columns #check that with columns
# Out:
# Index(['BEL', 'aminoacid_Code_1', 'aminoacid_Code_2', 'function', 'list',
#        'modification', 'namespace', 'node_id.1', 'p_modType', 'position',
#        'undefined_namespace', 'valid_NSV', 'value'],
#       dtype='object')

# %%
# example Ö 
#mylist =[1,1,2,2,5,7,8,9]
#{x for x in mylist if x > 3}

# %%
df['namespace']
# Out:
# node_id
# 1            CHEBI
# 2            SCOMP
# 3             HGNC
# 4              NaN
# 5             HGNC
# 6              ADO
# 7            MESHD
# 8             HGNC
# 9              NaN
# 10            HGNC
# 11          MESHPP
# 12             NaN
# 13            HGNC
# 14            HGNC
# 15            HGNC
# 16            HGNC
# 17             NaN
# 18             ADO
# 19           CHEBI
# 20           CHEBI
# 21           CHEBI
# 22           CHEBI
# 23           CHEBI
# 24            HGNC
# 25            HGNC
# 26             NaN
# 27            HGNC
# 28            HGNC
# 29            HGNC
# 30            HGNC
#            ...
# 11898         HGNC
# 11899         NIFT
# 11900        dbSNP
# 11901         NIFT
# 11902         NIFT
# 11903         GOBP
# 11904         NIFT
# 11905        dbSNP
# 11906        dbSNP
# 11907         HGNC
# 11908         NIFT
# 11909         NIFT
# 11910          NaN
# 11911    UNDEFINED
# 11912         BRCO
# 11913          NaN
# 11914         HGNC
# 11915         NIFT
# 11916         NIFT
# 11917        dbSNP
# 11918         NIFT
# 11919         NIFT
# 11920         NIFT
# 11921         HGNC
# 11922        dbSNP
# 11923         NIFT
# 11924        dbSNP
# 11925         HGNC
# 11926          NaN
# 11927         NIFT
# Name: namespace, dtype: object

# %%
namespace_distribution = df.namespace.value_counts()
namespace_distribution # checking repititions
# Out:
# HGNC         7636
# MGI          1079
# RGD           636
# GOBP          612
# CHEBI         339
# UNDEFINED     296
# dbSNP         161
# MESHD         124
# SCHEM          79
# SFAM           78
# PMIBP          32
# MESHPP         26
# GOCC           25
# PMICHEM        21
# NIFT           20
# ADO            15
# PTS            14
# SCOMP           9
# BRCO            9
# CHEBIID         5
# PMIPFAM         5
# MESHCS          4
# CHEMBL          3
# SDIS            3
# PMIDIS          2
# PMICOMP         2
# Name: namespace, dtype: int64

# %% [markdown]
# Now we check if there could be more than one datatype per key. We can do this by iterating over the dictionary `dataTypes`. This time we have curly brackets surronding the list compression. This create a set.

# %%
df_short = pd.read_table(pathToFile, nrows=100)
df_short
# Out:
#     node_id                                                BEL  \
# 0         1               a(CHEBI:"gamma-secretase inhibitor")
# 1         2           complex(SCOMP:"gamma Secretase Complex")
# 2         3                                    p(HGNC:"BACE1")
# 3         4  reaction(reactants(p(HGNC:APP)),products(a(ADO...
# 4         5                                      p(HGNC:"APP")
# 5         6                                  a(ADO:"Abeta_42")
# 6         7                    path(MESHD:"Alzheimer Disease")
# 7         8                                   p(HGNC:"CLSTN1")
# 8         9               complex(p(HGNC:CLSTN1),p(HGNC:KLC1))
# 9        10                                     p(HGNC:"KLC1")
# 10       11                      bp(MESHPP:"Axonal Transport")
# 11       12  list(p(HGNC:PSEN1),p(HGNC:NCSTN),p(HGNC:APH1A)...
# 12       13                                    p(HGNC:"PSEN1")
# 13       14                                    p(HGNC:"NCSTN")
# 14       15                                    p(HGNC:"APH1A")
# 15       16                                    p(HGNC:"PSEN2")
# 16       17          list(a(ADO:"Abeta_42"),a(ADO:"Abeta_40"))
# 17       18                                  a(ADO:"Abeta_40")
# 18       19                          a(CHEBI:"phenanthroline")
# 19       20         a(CHEBI:"ethylenediaminetetraacetic acid")
# 20       21  a(CHEBI:"ethylene glycol bis(2-aminoethyl)tetr...
# 21       22                             a(CHEBI:"calcium(2+)")
# 22       23                           a(CHEBI:"magnesium(2+)")
# 23       24                                    p(HGNC:"ARRB2")
# 24       25                                     p(HGNC:"GPR3")
# 25       26              complex(p(HGNC:ARRB2), p(HGNC:APH1A))
# 26       27                                     p(HGNC:"PLD1")
# 27       28                                      g(HGNC:"APP")
# 28       29                      g(HGNC:"APP",sub(G,275341,C))
# 29       30                         p(HGNC:"APP",sub(V,717,L))
# ..      ...                                                ...
# 70       71                                     p(HGNC:"MAPT")
# 71       72               complex(SCOMP:"Calcineurin Complex")
# 72       73                                      p(HGNC:"BAD")
# 73       74                              p(HGNC:"BAD",pmod(P))
# 74       75                              bp(GOBP:"cell death")
# 75       76                              p(SFAM:"CREB Family")
# 76       77                      p(SFAM:"CREB Family",pmod(P))
# 77       78  reaction(reactants(p(HGNC:CDK5R1)),products(p(...
# 78       79                                   p(HGNC:"CDK5R1")
# 79       80                                     p(HGNC:"CDK5")
# 80       81                              p(SFAM:"CAPN Family")
# 81       82                             p(HGNC:"MAPT",pmod(P))
# 82       83                        bp(GOBP:"neuron apoptosis")
# 83       84                              p(SFAM:"GSK3 Family")
# 84       85                                    p(HGNC:"GSK3B")
# 85       86                 complex(p(HGNC:APP),p(HGNC:LMTK2))
# 86       87                                    p(HGNC:"LMTK2")
# 87       88                                      p(HGNC:"A2M")
# 88       89                        p(HGNC:"A2M",sub(V,1000,I))
# 89       90                                   g(dbSNP:"rs669")
# 90       91                                     p(HGNC:"OLR1")
# 91       92                                     p(HGNC:"LRP8")
# 92       93                                      p(HGNC:"FAS")
# 93       94                       bp(GOBP:"apoptotic process")
# 94       95                                    p(HGNC:"CASP8")
# 95       96                                     p(HGNC:"FADD")
# 96       97  composite(p(HGNC:CASP8),p(HGNC:FADD),a(ADO:"Ab...
# 97       98                                    p(HGNC:"CASP2")
# 98       99  a(PMICHEM:"Z-Tyr-Val-Ala-Asp(OMe)-Fluoromethyl...
# 99      100                                 p(HGNC:"MTRNR2L2")
#
#    aminoacid_Code_1 aminoacid_Code_2   function  list modification namespace  \
# 0               NaN              NaN          a   NaN          NaN     CHEBI
# 1               NaN              NaN    complex   NaN          NaN     SCOMP
# 2               NaN              NaN          p   NaN          NaN      HGNC
# 3               NaN              NaN   reaction   NaN          NaN       NaN
# 4               NaN              NaN          p   NaN          NaN      HGNC
# 5               NaN              NaN          a   NaN          NaN       ADO
# 6               NaN              NaN       path   NaN          NaN     MESHD
# 7               NaN              NaN          p   NaN          NaN      HGNC
# 8               NaN              NaN    complex  True          NaN       NaN
# 9               NaN              NaN          p   NaN          NaN      HGNC
# 10              NaN              NaN         bp   NaN          NaN    MESHPP
# 11              NaN              NaN       list  True          NaN       NaN
# 12              NaN              NaN          p   NaN          NaN      HGNC
# 13              NaN              NaN          p   NaN          NaN      HGNC
# 14              NaN              NaN          p   NaN          NaN      HGNC
# 15              NaN              NaN          p   NaN          NaN      HGNC
# 16              NaN              NaN       list  True          NaN       NaN
# 17              NaN              NaN          a   NaN          NaN       ADO
# 18              NaN              NaN          a   NaN          NaN     CHEBI
# 19              NaN              NaN          a   NaN          NaN     CHEBI
# 20              NaN              NaN          a   NaN          NaN     CHEBI
# 21              NaN              NaN          a   NaN          NaN     CHEBI
# 22              NaN              NaN          a   NaN          NaN     CHEBI
# 23              NaN              NaN          p   NaN          NaN      HGNC
# 24              NaN              NaN          p   NaN          NaN      HGNC
# 25              NaN              NaN    complex  True          NaN       NaN
# 26              NaN              NaN          p   NaN          NaN      HGNC
# 27              NaN              NaN          g   NaN          NaN      HGNC
# 28                G                C          g   NaN          sub      HGNC
# 29                V                L          p   NaN          sub      HGNC
# ..              ...              ...        ...   ...          ...       ...
# 70              NaN              NaN          p   NaN          NaN      HGNC
# 71              NaN              NaN    complex   NaN          NaN     SCOMP
# 72              NaN              NaN          p   NaN          NaN      HGNC
# 73              NaN              NaN          p   NaN         pmod      HGNC
# 74              NaN              NaN         bp   NaN          NaN      GOBP
# 75              NaN              NaN          p   NaN          NaN      SFAM
# 76              NaN              NaN          p   NaN         pmod      SFAM
# 77              NaN              NaN   reaction   NaN          NaN       NaN
# 78              NaN              NaN          p   NaN          NaN      HGNC
# 79              NaN              NaN          p   NaN          NaN      HGNC
# 80              NaN              NaN          p   NaN          NaN      SFAM
# 81              NaN              NaN          p   NaN         pmod      HGNC
# 82              NaN              NaN         bp   NaN          NaN      GOBP
# 83              NaN              NaN          p   NaN          NaN      SFAM
# 84              NaN              NaN          p   NaN          NaN      HGNC
# 85              NaN              NaN    complex  True          NaN       NaN
# 86              NaN              NaN          p   NaN          NaN      HGNC
# 87              NaN              NaN          p   NaN          NaN      HGNC
# 88                V                I          p   NaN          sub      HGNC
# 89              NaN              NaN          g   NaN          NaN     dbSNP
# 90              NaN              NaN          p   NaN          NaN      HGNC
# 91              NaN              NaN          p   NaN          NaN      HGNC
# 92              NaN              NaN          p   NaN          NaN      HGNC
# 93              NaN              NaN         bp   NaN          NaN      GOBP
# 94              NaN              NaN          p   NaN          NaN      HGNC
# 95              NaN              NaN          p   NaN          NaN      HGNC
# 96              NaN              NaN  composite  True          NaN       NaN
# 97              NaN              NaN          p   NaN          NaN      HGNC
# 98              NaN              NaN          a   NaN          NaN   PMICHEM
# 99              NaN              NaN          p   NaN          NaN      HGNC
#
#     node_id.1 p_modType  position  undefined_namespace valid_NSV  \
# 0           1       NaN       NaN                  NaN       NaN
# 1           2       NaN       NaN                  NaN       NaN
# 2           3       NaN       NaN                  NaN      True
# 3           4       NaN       NaN                  NaN       NaN
# 4           5       NaN       NaN                  NaN      True
# 5           6       NaN       NaN                  NaN      True
# 6           7       NaN       NaN                  NaN      True
# 7           8       NaN       NaN                  NaN      True
# 8           9       NaN       NaN                  NaN       NaN
# 9          10       NaN       NaN                  NaN      True
# 10         11       NaN       NaN                  NaN      True
# 11         12       NaN       NaN                  NaN       NaN
# 12         13       NaN       NaN                  NaN      True
# 13         14       NaN       NaN                  NaN      True
# 14         15       NaN       NaN                  NaN      True
# 15         16       NaN       NaN                  NaN      True
# 16         17       NaN       NaN                  NaN       NaN
# 17         18       NaN       NaN                  NaN      True
# 18         19       NaN       NaN                  NaN      True
# 19         20       NaN       NaN                  NaN      True
# 20         21       NaN       NaN                  NaN       NaN
# 21         22       NaN       NaN                  NaN      True
# 22         23       NaN       NaN                  NaN      True
# 23         24       NaN       NaN                  NaN      True
# 24         25       NaN       NaN                  NaN      True
# 25         26       NaN       NaN                  NaN       NaN
# 26         27       NaN       NaN                  NaN      True
# 27         28       NaN       NaN                  NaN      True
# 28         29       NaN  275341.0                  NaN      True
# 29         30       NaN     717.0                  NaN      True
# ..        ...       ...       ...                  ...       ...
# 70         71       NaN       NaN                  NaN      True
# 71         72       NaN       NaN                  NaN       NaN
# 72         73       NaN       NaN                  NaN      True
# 73         74         P       NaN                  NaN      True
# 74         75       NaN       NaN                  NaN      True
# 75         76       NaN       NaN                  NaN      True
# 76         77         P       NaN                  NaN      True
# 77         78       NaN       NaN                  NaN       NaN
# 78         79       NaN       NaN                  NaN      True
# 79         80       NaN       NaN                  NaN      True
# 80         81       NaN       NaN                  NaN      True
# 81         82         P       NaN                  NaN      True
# 82         83       NaN       NaN                  NaN       NaN
# 83         84       NaN       NaN                  NaN      True
# 84         85       NaN       NaN                  NaN      True
# 85         86       NaN       NaN                  NaN       NaN
# 86         87       NaN       NaN                  NaN      True
# 87         88       NaN       NaN                  NaN      True
# 88         89       NaN    1000.0                  NaN      True
# 89         90       NaN       NaN                  NaN      True
# 90         91       NaN       NaN                  NaN      True
# 91         92       NaN       NaN                  NaN      True
# 92         93       NaN       NaN                  NaN      True
# 93         94       NaN       NaN                  NaN      True
# 94         95       NaN       NaN                  NaN      True
# 95         96       NaN       NaN                  NaN      True
# 96         97       NaN       NaN                  NaN       NaN
# 97         98       NaN       NaN                  NaN      True
# 98         99       NaN       NaN                  NaN       NaN
# 99        100       NaN       NaN                  NaN      True
#
#                                                 value
# 0                           gamma-secretase inhibitor
# 1                           "gamma Secretase Complex"
# 2                                               BACE1
# 3                                                 NaN
# 4                                                 APP
# 5                                            Abeta_42
# 6                                   Alzheimer Disease
# 7                                              CLSTN1
# 8                                                 NaN
# 9                                                KLC1
# 10                                   Axonal Transport
# 11                                                NaN
# 12                                              PSEN1
# 13                                              NCSTN
# 14                                              APH1A
# 15                                              PSEN2
# 16                                                NaN
# 17                                           Abeta_40
# 18                                     phenanthroline
# 19                    ethylenediaminetetraacetic acid
# 20  ethylene glycol bis(2-aminoethyl)tetraacetic a...
# 21                                        calcium(2+)
# 22                                      magnesium(2+)
# 23                                              ARRB2
# 24                                               GPR3
# 25                                                NaN
# 26                                               PLD1
# 27                                                APP
# 28                                                APP
# 29                                                APP
# ..                                                ...
# 70                                               MAPT
# 71                              "Calcineurin Complex"
# 72                                                BAD
# 73                                                BAD
# 74                                         cell death
# 75                                        CREB Family
# 76                                        CREB Family
# 77                                                NaN
# 78                                             CDK5R1
# 79                                               CDK5
# 80                                        CAPN Family
# 81                                               MAPT
# 82                                   neuron apoptosis
# 83                                        GSK3 Family
# 84                                              GSK3B
# 85                                                NaN
# 86                                              LMTK2
# 87                                                A2M
# 88                                                A2M
# 89                                              rs669
# 90                                               OLR1
# 91                                               LRP8
# 92                                                FAS
# 93                                  apoptotic process
# 94                                              CASP8
# 95                                               FADD
# 96                                                NaN
# 97                                              CASP2
# 98          Z-Tyr-Val-Ala-Asp(OMe)-Fluoromethylketone
# 99                                           MTRNR2L2
#
# [100 rows x 14 columns]

# %%
for bel in df_short.BEL:
    print(bel) # read bel
# Out:
# a(CHEBI:"gamma-secretase inhibitor")
# complex(SCOMP:"gamma Secretase Complex")
# p(HGNC:"BACE1")
# reaction(reactants(p(HGNC:APP)),products(a(ADO:"Abeta_42")))
# p(HGNC:"APP")
# a(ADO:"Abeta_42")
# path(MESHD:"Alzheimer Disease")
# p(HGNC:"CLSTN1")
# complex(p(HGNC:CLSTN1),p(HGNC:KLC1))
# p(HGNC:"KLC1")
# bp(MESHPP:"Axonal Transport")
# list(p(HGNC:PSEN1),p(HGNC:NCSTN),p(HGNC:APH1A),p(HGNC:PSEN2))
# p(HGNC:"PSEN1")
# p(HGNC:"NCSTN")
# p(HGNC:"APH1A")
# p(HGNC:"PSEN2")
# list(a(ADO:"Abeta_42"),a(ADO:"Abeta_40"))
# a(ADO:"Abeta_40")
# a(CHEBI:"phenanthroline")
# a(CHEBI:"ethylenediaminetetraacetic acid")
# a(CHEBI:"ethylene glycol bis(2-aminoethyl)tetraacetic acid ")
# a(CHEBI:"calcium(2+)")
# a(CHEBI:"magnesium(2+)")
# p(HGNC:"ARRB2")
# p(HGNC:"GPR3")
# complex(p(HGNC:ARRB2), p(HGNC:APH1A))
# p(HGNC:"PLD1")
# g(HGNC:"APP")
# g(HGNC:"APP",sub(G,275341,C))
# p(HGNC:"APP",sub(V,717,L))
# p(HGNC:"PSEN2",sub(N,141,I))
# g(HGNC:"APP",sub(G,717,C))
# p(HGNC:"PSEN1",sub(E,280,A))
# p(HGNC:"APOE")
# p(HGNC:"APOE",sub(R,132,S))
# g(HGNC:"CD44")
# g(dbSNP:"rs187116")
# g(HGNC:"NPHP1")
# g(dbSNP:"rs10173717")
# g(HGNC:"CADPS2")
# g(dbSNP:"rs3757536")
# g(HGNC:"GREM2")
# g(dbSNP:"rs12129547")
# g(dbSNP:"rs11542041")
# complex(p(HGNC:"APP"),a(CHEBI:"iron(2+)"))
# a(CHEBI:"iron(2+)")
# a(CHEBI:"hydrogen peroxide")
# complex(p(HGNC:"APP"),a(CHEBI:"copper(1+)"))
# a(CHEBI:"copper(1+)")
# bp(GOBP:"response to oxidative stress")
# bp(GOBP:"mitochondrial calcium ion transport")
# bp(GOBP:"mitochondrial calcium ion homeostasis")
# bp(GOBP:"electron transport chain")
# a(CHEBI:"superoxide")
# a(CHEBI:"ATP")
# bp(GOBP:"calcium ion homeostasis")
# complex(a(CHEBI:"hydrogen peroxide"),a(CHEBI:"iron(2+)"))
# a(CHEBI:"hydroxy group")
# a(SCHEM:"isoprostane")
# p(HGNC:"BACE2")
# p(HGNC:"CASP4")
# bp(GOBP:"microglial cell activation involved in immune response")
# a(BRCO:"Microglia")
# bp(PTS:"inflammatory response pathway")
# path(MESHD:"Neurogenic Inflammation")
# bp(GOBP:"reactive oxygen species metabolic process")
# a(CHEBI:"nitric oxide")
# bp(GOBP:"neuron apoptotic process")
# p(HGNC:"TNF")
# p(HGNC:"IL1B")
# p(HGNC:"MAPT")
# complex(SCOMP:"Calcineurin Complex")
# p(HGNC:"BAD")
# p(HGNC:"BAD",pmod(P))
# bp(GOBP:"cell death")
# p(SFAM:"CREB Family")
# p(SFAM:"CREB Family",pmod(P))
# reaction(reactants(p(HGNC:CDK5R1)),products(p(HGNC:CDK5)))
# p(HGNC:"CDK5R1")
# p(HGNC:"CDK5")
# p(SFAM:"CAPN Family")
# p(HGNC:"MAPT",pmod(P))
# bp(GOBP:"neuron apoptosis")
# p(SFAM:"GSK3 Family")
# p(HGNC:"GSK3B")
# complex(p(HGNC:APP),p(HGNC:LMTK2))
# p(HGNC:"LMTK2")
# p(HGNC:"A2M")
# p(HGNC:"A2M",sub(V,1000,I))
# g(dbSNP:"rs669")
# p(HGNC:"OLR1")
# p(HGNC:"LRP8")
# p(HGNC:"FAS")
# bp(GOBP:"apoptotic process")
# p(HGNC:"CASP8")
# p(HGNC:"FADD")
# composite(p(HGNC:CASP8),p(HGNC:FADD),a(ADO:"Abeta_42"))
# p(HGNC:"CASP2")
# a(PMICHEM:"Z-Tyr-Val-Ala-Asp(OMe)-Fluoromethylketone")
# p(HGNC:"MTRNR2L2")

# %%
for v in df_short.value:
    print(v) # read balue
# Out:
# gamma-secretase inhibitor
# "gamma Secretase Complex"
# BACE1
# nan
# APP
# Abeta_42
# Alzheimer Disease
# CLSTN1
# nan
# KLC1
# Axonal Transport
# nan
# PSEN1
# NCSTN
# APH1A
# PSEN2
# nan
# Abeta_40
# phenanthroline
# ethylenediaminetetraacetic acid
# ethylene glycol bis(2-aminoethyl)tetraacetic acid
# calcium(2+)
# magnesium(2+)
# ARRB2
# GPR3
# nan
# PLD1
# APP
# APP
# APP
# PSEN2
# APP
# PSEN1
# APOE
# APOE
# CD44
# rs187116
# NPHP1
# rs10173717
# CADPS2
# rs3757536
# GREM2
# rs12129547
# rs11542041
# nan
# iron(2+)
# hydrogen peroxide
# nan
# copper(1+)
# response to oxidative stress
# mitochondrial calcium ion transport
# mitochondrial calcium ion homeostasis
# electron transport chain
# superoxide
# ATP
# calcium ion homeostasis
# nan
# hydroxy group
# isoprostane
# BACE2
# CASP4
# microglial cell activation involved in immune response
# Microglia
# inflammatory response pathway
# Neurogenic Inflammation
# reactive oxygen species metabolic process
# nitric oxide
# neuron apoptotic process
# TNF
# IL1B
# MAPT
# "Calcineurin Complex"
# BAD
# BAD
# cell death
# CREB Family
# CREB Family
# nan
# CDK5R1
# CDK5
# CAPN Family
# MAPT
# neuron apoptosis
# GSK3 Family
# GSK3B
# nan
# LMTK2
# A2M
# A2M
# rs669
# OLR1
# LRP8
# FAS
# apoptotic process
# CASP8
# FADD
# nan
# CASP2
# Z-Tyr-Val-Ala-Asp(OMe)-Fluoromethylketone
# MTRNR2L2

# %%
df['1-to1'] = df.function + "(" + df.namespace + ':"' + df.value + '")' # create new column
df.loc[:,['BEL','1-to1']].head()
# Out:
#                                                        BEL  \
# node_id
# 1                     a(CHEBI:"gamma-secretase inhibitor")
# 2                 complex(SCOMP:"gamma Secretase Complex")
# 3                                          p(HGNC:"BACE1")
# 4        reaction(reactants(p(HGNC:APP)),products(a(ADO...
# 5                                            p(HGNC:"APP")
#
#                                               1-to1
# node_id
# 1              a(CHEBI:"gamma-secretase inhibitor")
# 2        complex(SCOMP:""gamma Secretase Complex"")
# 3                                   p(HGNC:"BACE1")
# 4                                               NaN
# 5                                     p(HGNC:"APP")

# %%
# create a list of columns(1-1) which can be used for the  in the main table because they are 1-to-1 and 
# a list of columns with more than value 
for bel in df.BEL:
    booleans = []
    #if BEL[bel]== ',':
        # booleans.append(True)
    if BEL[bel]==('list'):
         booleans.append(False)
    else:
        booleans.append(False)
    
#print(BEL, row.function, row.namespace, row.value)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-328a1222df73> in <module>()
#       5     #if BEL[bel]== ',':
#       6         # booleans.append(True)
# ----> 7     if BEL[bel]==('list'):
#       8          booleans.append(False)
#       9     else:
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# Let's create automatically the main table `gene` with `to_sql` method of `pandas.DataFrame`. Exclude the columns which

# %%
# load the json into a DataFrame as we did it before
# 1. all columns in the table named 'gene'
# 2. create dynamically first DataFrames and then
#    tables named as the columns with 1-to-many relation. Store also the foreign key in this DataFrame 
# trick : itearete all columns then create new data faram and save this frame in table

# %%
# Code 1

# %% [markdown]
# Check this MySQL website [Schema Object Names](http://dev.mysql.com/doc/refman/5.7/en/identifiers.html) for valid column names.
#
# [0-9a-zA-Z$_] are allowed characters

# %%
# correct column names with regex( regular expressions)

# %% [markdown]
# Let's rename our columns in the dataframe

# %% [markdown]
# ### 1-to1

# %% [markdown]
# ### 1-to-many
